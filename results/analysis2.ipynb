# %%
import pandas
# %matplotlib inline
import matplotlib.pyplot as plt
fig_size = [12, 9]
plt.rcParams["figure.figsize"] = fig_size

# %%
df = pandas.read_csv('runtime.csv')
#build_graph["name"] = build_graph.dataset.str.cat(build_graph.k.str)

#a = df.ix[:,[True, False, False, True, True, True, True]]
a = df[['dataset','uwise+','uwise','pwise','baseline']]
a.plot(kind='bar', x='dataset', logy=True, title='')

# %%
df = pandas.read_csv('runtime.csv')
#build_graph["name"] = build_graph.dataset.str.cat(build_graph.k.str)

#a = df.ix[:,[True, False, False, True, True, True, True]]
a = df[['dataset','uwise+','uwise','pwise','baseline']]
a.plot(kind='bar', x='dataset', logy=True, title='')
